# %%
import pandas as pd

import unzip

# %%
df = pd.read_csv('table.csv')
df
# Out:
#                    cache      id
# 0       LfJRTf1jOzll7chy  151550
# 1       tsDqYXtvPkd-LoZy  500333
# 2       hGPf8k0Ixp_ANvy6  970133
# 3       7Tc9S!3u7DeQEDkX  777699
# 4       B_xgHecEHrvvVPwB  447845
# ...                  ...     ...
# 499995  _UdxsbPO7ZP5xtXl  888182
# 499996  p!glKVT4jn6Mb5NI  140156
# 499997  ip5UdhRhhp2g0KRW  472528
# 499998  nZvc!aEaBHBTMonr  808924
# 499999  mAAsXEyoP09g_h8j  427126
#
# [500000 rows x 2 columns]

# %%
unique_ids = df['id'].value_counts()
unique_ids
# Out:
# id
# 251203    6
# 544664    6
# 501179    6
# 336399    6
# 808645    6
#          ..
# 47018     1
# 787258    1
# 912083    1
# 769917    1
# 427126    1
# Name: count, Length: 393548, dtype: int64

# %%
three_times = unique_ids[unique_ids == 3]
print(f"The following values were encountered three times: {three_times.index.tolist()}")
# Out:
# The following values were encountered three times: [374572, 52027, 237956, 766796, 783919, 403351, 748137, 927551, 506563, 612607, 138159, 363212, 157646, 946281, 214150, 172409, 601879, 253811, 170759, 56962, 616086, 489121, 979447, 876659, 733476, 960295, 431293, 335853, 950258, 600452, 735658, 378590, 773613, 572266, 12633, 747546, 346001, 549619, 645127, 920887, 429795, 463394, 794916, 731788, 785245, 804525, 969738, 55570, 635388, 546665, 764056, 594345, 836739, 439765, 155589, 642819, 152396, 115874, 331885, 886462, 328721, 509290, 987607, 706713, 619937, 556500, 816532, 765821, 825644, 707681, 665220, 367647, 862624, 780820, 171614, 516405, 353521, 252622, 136964, 101725, 646836, 922889, 789945, 762956, 396908, 412183, 173638, 848651, 90038, 691446, 981375, 518598, 548548, 616838, 410934, 523892, 959634, 340704, 484443, 713295, 687703, 276132, 506414, 931233, 190416, 321036, 453407, 929010, 951454, 416965, 973943, 824513, 750780, 954362, 738416, 714645, 296494, 508943, 515477,
# ...

# %%
repeats = unique_ids.value_counts()

results = zip(repeats.index, repeats.values)
for result in results:
    times, unique_ids = result
    print(f"Here's how many ids repeat {times} times: {unique_ids}")
# Out:
# Here's how many ids repeat 1 times: 303441
# Here's how many ids repeat 2 times: 75779
# Here's how many ids repeat 3 times: 12511
# Here's how many ids repeat 4 times: 1630
# Here's how many ids repeat 5 times: 174
# Here's how many ids repeat 6 times: 13
